# %% [markdown]
# # Reading and Handling Shapefile Data Using GeoPandas
#
# ### Prerequisites
# To get started with reading Shapefile data in Python using GeoPandas, ensure you have the following:
#
# - **GeoPandas**: A powerful library for working with geospatial data.
# - **Python**: A programming language used for data analysis and scripting.
# - **Conda Environment** (optional): A convenient way to manage packages and dependencies.

# %%
# !pip install geopandas

# %%
import geopandas as gpd

# %%
in_geojson = r'C:\Users\SD-LORENZO-PC\pyproject\rndPy\Geospatial\dataset\data\shp\municipality.json'
in_shp = r'C:\Users\SD-LORENZO-PC\pyproject\rndPy\Geospatial\dataset\data\shp\municipality.shp'

# %%
gdf = gpd.read_file(in_geojson)

# %%
gdf.head(10)
# Out:
#    OBJECTID   DISTRICT             GaPa_NaPa      Type_GN Province  SCode  \
# 0         1  TAPLEJUNG       Aathrai Tribeni   Gaunpalika        1      1
# 1         2  TAPLEJUNG            Maiwakhola   Gaunpalika        1      1
# 2         3  TAPLEJUNG             Meringden   Gaunpalika        1      1
# 3         4  TAPLEJUNG            Mikwakhola   Gaunpalika        1      1
# 4         5  TAPLEJUNG          Phaktanglung   Gaunpalika        1      1
# 5         6  TAPLEJUNG             Phungling  Nagarpalika        1      1
# 6         7  TAPLEJUNG              Sidingba   Gaunpalika        1      1
# 7         8  TAPLEJUNG            Sirijangha   Gaunpalika        1      1
# 8         9  TAPLEJUNG  Pathibhara Yangwarak   Gaunpalika        1      1
# 9        10  PANCHTHAR              Falelung   Gaunpalika        1      1
#
#    DCode  SDD  MCode      length         area  SDDMM          Nepali  \
# 0      1  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी
# ...

# %%
len(gdf)
# Out:
# 774

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 769    Polygon
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# Length: 774, dtype: object

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot("DISTRICT")
# Out:
# <Axes: >

# %%
gdf.plot('Province', legend=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, figsize=(4.5, 10))
gdf.plot(ax=ax, column='Province', legend=True, legend_kwds={"loc": 'center left'})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04, 0.5))

# %%
gdf.to_file(r'C:\Users\SD-LORENZO-PC\pyproject\rndPy\Geospatial\dataset\data\shp\output\out_shp.shp')

# %%
gdf.to_file(r'C:\Users\SD-LORENZO-PC\pyproject\rndPy\Geospatial\dataset\data\shp\output\out_geojson.geojson', driver='GeoJSON', encoding="utf-8")
